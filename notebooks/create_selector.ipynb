# %%
# %load_ext kedro.extras.extensions.ipython
# Out:
# 2022-06-19 23:11:55,846 - kedro.extras.extensions.ipython - INFO - Updated path to Kedro project: /Users/jordan/Library/Mobile Documents/com~apple~CloudDocs/Code/University/Revisions/sunspots
# 2022-06-19 23:11:56,634 - kedro.framework.session.store - INFO - `read()` not implemented for `BaseSessionStore`. Assuming empty store.
# 2022-06-19 23:11:56,713 - kedro.framework.session.session - WARNING - Unable to git describe /Users/jordan/Library/Mobile Documents/com~apple~CloudDocs/Code/University/Revisions/sunspots
# 2022-06-19 23:12:01,620 - kedro.extras.extensions.ipython - INFO - ** Kedro project Sunspots
# 2022-06-19 23:12:01,622 - kedro.extras.extensions.ipython - INFO - Defined global variable `context`, `session`, `catalog` and `pipelines`
# 2022-06-19 23:12:04,200 - kedro.extras.extensions.ipython - INFO - Registered line magic `run_viz`

# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
plt.style.use('seaborn')
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
# %matplotlib widget
from sunspots.extras.utils.sunspot_selector import SunspotSelector

# %%
dataset = catalog.load("remote_training_dataset")
# Out:
# 2022-06-19 23:12:07,773 - kedro.io.data_catalog - INFO - Loading data from `remote_training_dataset` (PartitionedDataSet)...

# %%
# SS = SunspotSelector(dataset, "remote_training_dataset", pixels_per_cell=(64,64))
# Out:
# IntSlider(value=0, description='File Number', max=59)
# Button(description='Clear Image', style=ButtonStyle())
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# catalog.save("remote_sunspot_selector", SS)
# Out:
# 2022-06-19 23:28:01,619 - kedro.io.data_catalog - INFO - Saving data to `remote_sunspot_selector` (PickleDataSet)...
