# %%
# %load_ext kedro.extras.extensions.ipython
# Out:
# [08/27/22 14:45:04] INFO     Updated path to Kedro project: /Users/jordan/Library/Mobile              ]8;id=404890;file:///Users/jordan/mambaforge/envs/sunspots/lib/python3.10/site-packages/kedro/extras/extensions/ipython.py\ipython.py]8;;\:]8;id=300551;file:///Users/jordan/mambaforge/envs/sunspots/lib/python3.10/site-packages/kedro/extras/extensions/ipython.py#53\53]8;;\
#                              Documents/com~apple~CloudDocs/Code/University/Revisions/sunspots
# 2022-08-27 14:45:09,376 - kedro.extras.extensions.ipython - INFO - Kedro project Sunspots
# 2022-08-27 14:45:09,378 - kedro.extras.extensions.ipython - INFO - Defined global variable 'context', 'session', 'catalog' and 'pipelines'
# 2022-08-27 14:45:10,726 - kedro.extras.extensions.ipython - INFO - Registered line magic 'run_viz'

# %%
# %reload_ext kedro.extras.extensions.ipython
# Out:
# 2022-08-27 14:45:11,760 - kedro.extras.extensions.ipython - INFO - Updated path to Kedro project: /Users/jordan/Library/Mobile Documents/com~apple~CloudDocs/Code/University/Revisions/sunspots
# 2022-08-27 14:45:12,458 - kedro.extras.extensions.ipython - INFO - Kedro project Sunspots
# 2022-08-27 14:45:12,460 - kedro.extras.extensions.ipython - INFO - Defined global variable 'context', 'session', 'catalog' and 'pipelines'
# 2022-08-27 14:45:12,484 - kedro.extras.extensions.ipython - INFO - Registered line magic 'run_viz'

# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
plt.style.use('seaborn')
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
# %matplotlib widget
from sunspots.extras.utils.sunspot_selector import SunspotSelector

# %%
dataset = catalog.load("validation_dataset")
dataset
# Out:
# 2022-08-27 14:45:18,434 - kedro.io.data_catalog - INFO - Loading data from 'validation_dataset' (PartitionedDataSet)...
# {
#     'hmi_ic_45s_2011_05_21_00_01_30_tai_continuum': <bound method AbstractVersionedDataSet.load of <sunspots.extras.datasets.sunpy_datasets.SunPyMapDataSet object at 0x10c8c7520>>,
#     'hmi_ic_45s_2011_05_28_00_01_30_tai_continuum': <bound method AbstractVersionedDataSet.load of <sunspots.extras.datasets.sunpy_datasets.SunPyMapDataSet object at 0x129c883a0>>,
#     'hmi_ic_45s_2012_09_29_00_01_30_tai_continuum': <bound method AbstractVersionedDataSet.load of <sunspots.extras.datasets.sunpy_datasets.SunPyMapDataSet object at 0x12bd12770>>,
#     'hmi_ic_45s_2013_08_31_00_01_30_tai_continuum': <bound method AbstractVersionedDataSet.load of <sunspots.extras.datasets.sunpy_datasets.SunPyMapDataSet object at 0x12bd130d0>>,
# ...

# %%
SS = SunspotSelector(dataset, "validation_dataset", pixels_per_cell=(64,64))
# Out:
# IntSlider(value=0, description='File Number', max=4)
# Button(description='Clear Image', style=ButtonStyle())
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# catalog.save("validation_sunspot_selector", SS)
# Out:
# 2022-08-27 14:46:06,896 - kedro.io.data_catalog - INFO - Saving data to 'validation_sunspot_selector' (PickleDataSet)...
