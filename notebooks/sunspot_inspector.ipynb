# %%
# %load_ext kedro.ipython
# %reload_kedro
# Out:
# [11/17/22 04:50:12] INFO     Updated path to Kedro project: /Users/jordan/repos/sunspots             ]8;id=414914;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=372797;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py#54\54]8;;\
# [11/17/22 04:50:19] INFO     Project path: /Users/jordan/repos/sunspots                                 ]8;id=408960;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=228880;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#19\19]8;;\
# ...

# %%
from sunspots.extras.utils.sunspot_inspector import SunspotInspector
import warnings
import matplotlib.pyplot as plt

# %%
warnings.filterwarnings("ignore")
# %matplotlib widget
plt.style.use('seaborn')
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %%
catalog.list()
# Out:
# [
#     'training_dataset',
#     'sunspot_selector',
#     'image_chunk_features',
#     'image_chunk_labels',
#     'engineered_features',
#     'fit_engineer_features.scaler',
#     'feature_engineering.scaler',
#     'master_table',
#     'X_train',
#     'X_test',
#     'y_train',
#     'y_test',
#     'X_train_resampled',
#     'y_train_resampled',
#     'model',
#     'target_prediction.model',
#     'training_targets',
#     'parameters',
#     'params:features',
#     'params:modelling',
#     'params:modelling.resample_options',
#     'params:modelling.resample_options.mode',
#     'params:modelling.resample_options.ratio',
#     'params:datasets',
#     'params:datasets.20140130Timeseries',
#     'params:datasets.20140130Timeseries.start_time',
#     'params:datasets.20140130Timeseries.end_time',
#     'params:datasets.20140130Timeseries.interval',
#     'params:datasets.20140212Timeseries',
#     'params:datasets.20140212Timeseries.start_time',
# ...

# %%
dataset = catalog.load("20140910Timeseries")
targets = catalog.load("20140910_targets")
box_size = catalog.load("params:box_size")
# Out:
#                     INFO     Loading data from '20140910Timeseries' (PartitionedDataSet)...     ]8;id=646549;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=988171;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# [11/17/22 04:50:24] INFO     Loading data from '20140910_targets' (PickleDataSet)...            ]8;id=440806;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=62930;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# ...

# %%
SunspotInspector(dataset, targets, plot_regions=True)
# Out:
# IntSlider(value=0, description='File Number', max=23)
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
