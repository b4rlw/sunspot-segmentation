# %%
# %load_ext kedro.ipython
# Out:
# [11/17/22 04:52:17] INFO     Updated path to Kedro project: /Users/jordan/repos/sunspots             ]8;id=863753;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=956958;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py#54\54]8;;\
# [11/17/22 04:52:22] INFO     Project path: /Users/jordan/repos/sunspots                                 ]8;id=249320;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=170744;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#19\19]8;;\
#                     INFO     Loading data from 'params:datasets' (MemoryDataSet)...             ]8;id=902163;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=309595;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\
#                     INFO     Added dataset '20140130Timeseries' to the data catalog.                    ]8;id=294857;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=820023;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140130_targets' to the data catalog.                      ]8;id=415455;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=366901;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#53\53]8;;\
#                     INFO     Added dataset '20140130_region_submaps' to the data catalog.               ]8;id=763539;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=94021;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140212Timeseries' to the data catalog.                    ]8;id=614394;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=305000;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140212_targets' to the data catalog.                      ]8;id=665038;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=119722;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#53\53]8;;\
#                     INFO     Added dataset '20140212_region_submaps' to the data catalog.               ]8;id=828414;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=764463;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140413Timeseries' to the data catalog.                    ]8;id=516634;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=952294;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140413_targets' to the data catalog.                      ]8;id=995516;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=475008;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#53\53]8;;\
#                     INFO     Added dataset '20140413_region_submaps' to the data catalog.               ]8;id=838659;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=572886;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140509Timeseries' to the data catalog.                    ]8;id=854903;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=266464;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140509_targets' to the data catalog.                      ]8;id=83438;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=326985;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#53\53]8;;\
#                     INFO     Added dataset '20140509_region_submaps' to the data catalog.               ]8;id=233240;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=702932;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140704Timeseries' to the data catalog.                    ]8;id=353062;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=646714;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140704_targets' to the data catalog.                      ]8;id=180131;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=310990;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#53\53]8;;\
#                     INFO     Added dataset '20140704_region_submaps' to the data catalog.               ]8;id=686687;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=944823;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140910Timeseries' to the data catalog.                    ]8;id=211683;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=297887;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140910_targets' to the data catalog.                      ]8;id=937449;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=270493;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#53\53]8;;\
#                     INFO     Added dataset '20140910_region_submaps' to the data catalog.               ]8;id=871479;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=184493;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Kedro project sunspots                                                  ]8;id=35851;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=702331;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py#77\77]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and 'pipelines' ]8;id=689588;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=594600;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py#78\78]8;;\
# [11/17/22 04:52:24] INFO     Registered line magic 'run_viz'                                         ]8;id=311327;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=958272;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py#84\84]8;;\
#                     INFO     No path argument was provided. Using: /Users/jordan/repos/sunspots      ]8;id=706194;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=718872;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py#56\56]8;;\
# [11/17/22 04:52:25] INFO     Project path: /Users/jordan/repos/sunspots                                 ]8;id=977889;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=150301;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#19\19]8;;\
#                     INFO     Loading data from 'params:datasets' (MemoryDataSet)...             ]8;id=681083;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=949697;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\
#                     INFO     Added dataset '20140130Timeseries' to the data catalog.                    ]8;id=549495;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=851464;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140130_targets' to the data catalog.                      ]8;id=507293;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=963136;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#53\53]8;;\
#                     INFO     Added dataset '20140130_region_submaps' to the data catalog.               ]8;id=200167;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=581974;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140212Timeseries' to the data catalog.                    ]8;id=696122;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=847332;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140212_targets' to the data catalog.                      ]8;id=442500;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=68987;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#53\53]8;;\
#                     INFO     Added dataset '20140212_region_submaps' to the data catalog.               ]8;id=978057;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=686742;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140413Timeseries' to the data catalog.                    ]8;id=97475;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=764458;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140413_targets' to the data catalog.                      ]8;id=471834;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=804368;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#53\53]8;;\
#                     INFO     Added dataset '20140413_region_submaps' to the data catalog.               ]8;id=548568;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=769471;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140509Timeseries' to the data catalog.                    ]8;id=624460;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=341948;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140509_targets' to the data catalog.                      ]8;id=281810;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=947117;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#53\53]8;;\
#                     INFO     Added dataset '20140509_region_submaps' to the data catalog.               ]8;id=244243;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=193484;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140704Timeseries' to the data catalog.                    ]8;id=982864;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=640546;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140704_targets' to the data catalog.                      ]8;id=868457;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=115042;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#53\53]8;;\
#                     INFO     Added dataset '20140704_region_submaps' to the data catalog.               ]8;id=594774;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=77880;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140910Timeseries' to the data catalog.                    ]8;id=430603;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=7577;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Added dataset '20140910_targets' to the data catalog.                      ]8;id=915718;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=572590;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#53\53]8;;\
#                     INFO     Added dataset '20140910_region_submaps' to the data catalog.               ]8;id=764359;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=672625;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#40\40]8;;\
#                     INFO     Kedro project sunspots                                                  ]8;id=723457;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=279796;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py#77\77]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and 'pipelines' ]8;id=76870;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=896318;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py#78\78]8;;\
#                     INFO     Registered line magic 'run_viz'                                         ]8;id=32702;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=757554;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py#84\84]8;;\

# %%
from sunspots.extras.utils.sunspot_inspector import SunspotInspector
import warnings
import matplotlib.pyplot as plt

# %%
warnings.filterwarnings("ignore")
# %matplotlib widget
plt.style.use('seaborn')
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %%
catalog.list()
# Out:
# [
#     'training_dataset',
#     'sunspot_selector',
#     'image_chunk_features',
#     'image_chunk_labels',
#     'engineered_features',
#     'fit_engineer_features.scaler',
#     'feature_engineering.scaler',
#     'master_table',
#     'X_train',
#     'X_test',
#     'y_train',
#     'y_test',
#     'X_train_resampled',
#     'y_train_resampled',
#     'model',
#     'target_prediction.model',
#     'training_targets',
#     'parameters',
#     'params:features',
#     'params:modelling',
#     'params:modelling.resample_options',
#     'params:modelling.resample_options.mode',
#     'params:modelling.resample_options.ratio',
#     'params:datasets',
#     'params:datasets.20140130Timeseries',
#     'params:datasets.20140130Timeseries.start_time',
#     'params:datasets.20140130Timeseries.end_time',
#     'params:datasets.20140130Timeseries.interval',
#     'params:datasets.20140212Timeseries',
#     'params:datasets.20140212Timeseries.start_time',
#     'params:datasets.20140212Timeseries.end_time',
#     'params:datasets.20140212Timeseries.interval',
#     'params:datasets.20140413Timeseries',
#     'params:datasets.20140413Timeseries.start_time',
#     'params:datasets.20140413Timeseries.end_time',
#     'params:datasets.20140413Timeseries.interval',
#     'params:datasets.20140509Timeseries',
#     'params:datasets.20140509Timeseries.start_time',
#     'params:datasets.20140509Timeseries.end_time',
#     'params:datasets.20140509Timeseries.interval',
#     'params:datasets.20140704Timeseries',
#     'params:datasets.20140704Timeseries.start_time',
#     'params:datasets.20140704Timeseries.end_time',
#     'params:datasets.20140704Timeseries.interval',
#     'params:datasets.20140910Timeseries',
#     'params:datasets.20140910Timeseries.start_time',
#     'params:datasets.20140910Timeseries.end_time',
#     'params:datasets.20140910Timeseries.interval',
#     'params:box_size',
#     'params:split_options',
#     'params:split_options.target',
#     'params:split_options.test_size',
#     '20140130Timeseries',
#     '20140130_targets',
#     '20140130_region_submaps',
#     '20140212Timeseries',
#     '20140212_targets',
#     '20140212_region_submaps',
#     '20140413Timeseries',
#     '20140413_targets',
#     '20140413_region_submaps',
#     '20140509Timeseries',
#     '20140509_targets',
#     '20140509_region_submaps',
#     '20140704Timeseries',
#     '20140704_targets',
#     '20140704_region_submaps',
#     '20140910Timeseries',
#     '20140910_targets',
#     '20140910_region_submaps'
# ]

# %%
dataset = catalog.load("20140910Timeseries")
targets = catalog.load("20140910_targets")
box_size = catalog.load("params:box_size")
# Out:
#                     INFO     Loading data from '20140910Timeseries' (PartitionedDataSet)...     ]8;id=526670;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=192122;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# [11/17/22 04:52:26] INFO     Loading data from '20140910_targets' (PickleDataSet)...            ]8;id=351914;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=613458;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# [11/17/22 04:52:27] INFO     Loading data from 'params:box_size' (MemoryDataSet)...             ]8;id=714330;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=627382;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\

# %%
inspector = SunspotInspector(dataset, targets, plot_regions=True)
# Out:
# IntSlider(value=0, description='File Number', max=23)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
