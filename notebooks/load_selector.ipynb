# %%
import warnings
import matplotlib.pyplot as plt

# %%
# %load_ext kedro.ipython
# %reload_kedro
# Out:
# [08/14/22 18:47:50] INFO     Updated path to Kedro project: /Users/jordan/Library/Mobile              ]8;id=481927;file:///Users/jordan/mambaforge/envs/sunspots/lib/python3.10/site-packages/kedro/extras/extensions/ipython.py\ipython.py]8;;\:]8;id=743288;file:///Users/jordan/mambaforge/envs/sunspots/lib/python3.10/site-packages/kedro/extras/extensions/ipython.py#53\53]8;;\
#                              Documents/com~apple~CloudDocs/Code/University/Revisions/sunspots
# 2022-08-14 18:47:54,654 - kedro.extras.extensions.ipython - INFO - Kedro project Sunspots
# 2022-08-14 18:47:54,656 - kedro.extras.extensions.ipython - INFO - Defined global variable 'context', 'session', 'catalog' and 'pipelines'
# 2022-08-14 18:47:57,075 - py.warnings - WARNING - /Users/jordan/mambaforge/envs/sunspots/lib/python3.10/site-packages/plotly/graph_objects/__init__.py:288: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(ipywidgets.__version__) >= LooseVersion("7.0.0"):
#
# 2022-08-14 18:47:57,091 - kedro.extras.extensions.ipython - INFO - Registered line magic 'run_viz'
# 2022-08-14 18:47:57,095 - kedro.extras.extensions.ipython - INFO - No path argument was provided. Using: /Users/jordan/Library/Mobile Documents/com~apple~CloudDocs/Code/University/Revisions/sunspots
# 2022-08-14 18:47:57,877 - kedro.extras.extensions.ipython - INFO - Kedro project Sunspots
# 2022-08-14 18:47:57,879 - kedro.extras.extensions.ipython - INFO - Defined global variable 'context', 'session', 'catalog' and 'pipelines'
# 2022-08-14 18:47:57,926 - kedro.extras.extensions.ipython - INFO - Registered line magic 'run_viz'

# %%
warnings.filterwarnings("ignore")
# %matplotlib widget
plt.style.use('seaborn')
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %%
SS = catalog.load("sunspot_selector")
SS.dataset_name
# Out:
# 2022-08-14 18:52:30,180 - kedro.io.data_catalog - INFO - Loading data from 'sunspot_selector' (PickleDataSet)...
# 'training_dataset'

# %%
training_data = catalog.load(SS.dataset_name)
SS.display_widget(training_data)
# Out:
# 2022-08-14 18:52:33,130 - kedro.io.data_catalog - INFO - Loading data from 'training_dataset' (PartitionedDataSet)...
# IntSlider(value=0, description='File Number', max=59)
# Button(description='Clear Image', style=ButtonStyle())
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# catalog.save("sunspot_selector", SS)
