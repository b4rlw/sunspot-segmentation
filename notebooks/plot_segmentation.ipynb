# %%
# %load_ext kedro.ipython
# Out:
# [12/20/22 16:24:11] INFO     Updated path to Kedro project: /Users/jordan/repos/sunspots             ]8;id=613458;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=472526;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/ipython/__init__.py#54\54]8;;\
# [12/20/22 16:24:17] INFO     Project path: /Users/jordan/repos/sunspots                                 ]8;id=59447;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py\hooks.py]8;;\:]8;id=625329;file:///Users/jordan/repos/sunspots/src/sunspots/hooks.py#22\22]8;;\
# ...

# %%
catalog.list()
# Out:
# [
#     'training_dataset',
#     'sunspot_selector',
#     'image_patch_features',
#     'image_patch_labels',
#     'image_chunk_features',
#     'image_chunk_labels',
#     'engineered_features',
#     'fit_engineer_features.scaler',
#     'feature_engineering.scaler',
#     'master_table',
#     'X_train',
#     'X_test',
#     'y_train',
#     'y_test',
#     'X_train_resampled',
#     'y_train_resampled',
#     'model',
#     'target_prediction.model',
#     'training_targets',
#     'parameters',
#     'params:stara',
#     'params:stara.circle_radius',
#     'params:stara.median_box',
#     'params:stara.threshold',
#     'params:stara.limb_filter',
#     'params:features',
#     'params:modelling',
#     'params:modelling.resample_options',
#     'params:modelling.resample_options.mode',
#     'params:modelling.resample_options.ratio',
#     'params:datasets',
#     'params:datasets.20140130Timeseries',
#     'params:datasets.20140130Timeseries.start_time',
# ...

# %%
region_submaps = catalog.load("20140910_region_submaps")
segmentations = catalog.load("20140910_segmentations")
region_dataframes = catalog.load("20140910_region_dataframes")
# Out:
# [12/20/22 17:00:52] INFO     Loading data from '20140910_region_submaps'                        ]8;id=763527;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=595459;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\
#                              (PartitionedDataSet)...
#                     INFO     Loading data from '20140910_segmentations' (PartitionedDataSet)... ]8;id=620073;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=934879;file:///usr/local/Caskroom/mambaforge/base/envs/sunspots/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# ...

# %%
smap = region_submaps['hmi_ic_45s_2014_09_10_16_31_30_tai_continuum_(2320, 1936)_(2032, 1584)']()
seg = segmentations['hmi_ic_45s_2014_09_10_16_31_30_tai_continuum_(2320, 1936)_(2032, 1584)_segmentation']()
reg = region_dataframes['hmi_ic_45s_2014_09_10_16_31_30_tai_continuum_(2320, 1936)_(2032, 1584)_region_dataframe']()

# %%
import matplotlib.pyplot as plt
import IPython.display as display
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %%
fig, axes = plt.subplots(subplot_kw={"projection": smap})
smap.plot()
axes.contour(seg, levels=0)
plt.show()
display.display(reg)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>label</th>
#       <th>centroid-0</th>
#       <th>centroid-1</th>
#       <th>area</th>
#       <th>min_intensity</th>
#       <th>obstime</th>
#       <th>center_coord.lon</th>
#       <th>center_coord.lat</th>
#       <th>center_coord.radius</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>158.169517</td>
#       <td>162.162228</td>
#       <td>10701</td>
#       <td>5606.0</td>
#       <td>2014-09-10 16:30:35.800</td>
#       <td>-4.639001</td>
#       <td>16.373596</td>
#       <td>6.960000e+08</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...
